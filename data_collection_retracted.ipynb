# %%
import requests
import time
import csv

S2_API_KEY = "mWPieufPID4FlG6q3KC796rduRkqQjcl1c49CiRY"

unfound_papers = [
    {
        "reason": "Not found in retractionwatch database",
        "title": "Design and Implementation of Low-Power Wireless Sensor Networks for Environmental Monitoring",
    },
    {
        "reason": "Not found in retractionwatch database",
        "title": "Robust Virtual Inertia Control of an Islanded Microgrid Considering High Penetration of Renewable Energy",
    },
]

top_15_retracted_papers_by_citations_json = [
    {
        "title": "Dissipativity-Based Fuzzy Integral Sliding Mode Control of Continuous-Time T-S Fuzzy Systems",
        "doi": "10.1109/TFUZZ.2017.2710952",
        "id": "09f885deb1c88867c83cccafeeeaa468f91218e0",
        "retraction_date": "2022/11/20",
        "citations": 491,
    },
    {
        "title": "Deep learning system to screen coronavirus disease 2019 pneumonia",
        "doi": "10.1007/s10489-020-01714-3",
        "id": "35751010cf4b09552ed4c85b5a1367f96db2641f",
        "retraction_date": "2020/04/22",
        "citations": 467,
    },
    {
        "title": "New Delay-Dependent Exponential H∞ Synchronization for Uncertain Neural Networks With Mixed Time Delays",
        "doi": "10.1109/TSMCB.2009.2024408",
        "id": "a7ef5b17b8672f8e34b4f48372cd041a5fe1cb7a",
        "retraction_date": "2022/11/20",
        "citations": 417,
    },
    {
        "title": "Robust Observer Design for Unknown Inputs Takagi-Sugeno Models",
        "doi": "10.1109/TFUZZ.2012.2197215",
        "id": "11aaec241756a5c74539c4c3e4a8f40846d5a8be",
        "retraction_date": "2022/11/20",
        "citations": 340,
    },
    {
        "title": "Internet of Things (IoT) and its impact on supply chain: A framework for building smart, secure and efficient systems",
        "doi": "10.1016/j.future.2018.04.051",
        "id": "4700ba8f87463150d4ee8c81da3afa842914a69f",
        "retraction_date": "2021/12/09",
        "citations": 220,
    },
    {
        "title": "A hybrid whale optimization algorithm based on local search strategy for the permutation flow shop scheduling problem",
        "doi": "10.1016/j.future.2018.03.020",
        "id": "97312dbff6883d64af1a97eb0fdbf725f34be255",
        "retraction_date": "2021/10/01",
        "citations": 210,
    },
    {
        "title": "An integrated neutrosophic ANP and VIKOR method for achieving sustainable supplier selection: A case study in importing field",
        "doi": "10.1016/j.compind.2018.12.017",
        "id": "488bb9cb03c4f4b729254e9b2433c4420bc2afb7",
        "retraction_date": "2022/04/11",
        "citations": 202,
    },
    {
        "title": "A Novel Robust Fuzzy Integral Sliding Mode Control for Nonlinear Semi-Markovian Jump T-S Fuzzy Systems",
        "doi": "10.1109/TFUZZ.2018.2838552",
        "id": "74cc4e05ba11e18cb9f12f71343bd5c2f61c5ef2",
        "retraction_date": "2022/11/20",
        "citations": 173,
    },
    {
        "title": "Analysis of influential factors for predicting the shear strength of a V-shaped angle shear connector in composite beams using an adaptive neuro-fuzzy technique",
        "doi": "10.1007/s10845-017-1306-6",
        "id": "8f72fcda5aecfd783bc9d104c9d440445908654c",
        "retraction_date": "2019/11/12",
        "citations": 141,
    },
    {
        "title": "An Improved Result on Exponential Stabilization of Sampled-Data Fuzzy Systems",
        "doi": "10.1109/TFUZZ.2018.2852281",
        "id": "e4c5f336cf18b3824074a7cec61315fe0c817b64",
        "retraction_date": "2022/11/20",
        "citations": 140,
    },
    {
        "title": "Hybrid Recommendation System for Heart Disease Diagnosis based on Multiple Kernel Learning with Adaptive Neuro-Fuzzy Inference System",
        "doi": "10.1007/s11042-017-5515-y",
        "id": "d92689401ee861f27950cb7c54b68a2c72e91221",
        "retraction_date": "2022/09/13",
        "citations": 137,
    },
    {
        "title": "Evaluation of the green supply chain management practices: A novel neutrosophic approach",
        "doi": "10.1016/j.compind.2019.02.013",
        "id": "e464a501d6517dab519397190808665011b8c935",
        "retraction_date": "2022/04/11",
        "citations": 136,
    },
    {
        "title": "Hybrid optimization with cryptography encryption for medical image security in Internet of Things",
        "doi": "10.1007/s00521-018-3801-x",
        "id": "a1f13012212ddeb18f221acfef2233c3e1309800",
        "retraction_date": "2022/12/14",
        "citations": 135,
    },
    {
        "title": "Potential of soft computing approach for evaluating the factors affecting the capacity of steel-concrete composite beam",
        "doi": "10.1007/s10845-016-1217-y",
        "id": "bdb16b4371a6ae263832ad652d6deddee385bacb",
        "retraction_date": "2020/01/14",
        "citations": 135,
    },
    {
        "title": "An ontology-driven personalized food recommendation in IoT-based healthcare system",
        "doi": "10.1007/s11227-018-2331-8",
        "id": "ad6feba017433e098ceda3ca30af6975ecaa2bd6",
        "retraction_date": "2022/10/10",
        "citations": 113,
    },
]

# %%
def get_publication_date(paperId):
    # Making an API call to retrieve paper information including the publication date
    rsp = requests.get(
        "https://api.semanticscholar.org/graph/v1/paper/{}?fields=publicationDate".format(
            paperId
        ),
        headers={"x-api-key": S2_API_KEY},
    )

    try:
        rsp.raise_for_status()
        paper_info = rsp.json()
        # print(paper_info)
        if "publicationDate" in paper_info:
            # print("Publication date found for paperId: {}".format(paper_info['publicationDate']))
            return paper_info["publicationDate"]
        else:
            print("Publication date not found for paperId: {}".format(paperId))
            return None
    except requests.exceptions.HTTPError as e:
        print("Error fetching publication date for paperId {}: {}".format(paperId, e))
        return None

# %%
import os

def create_csv_file(paperId, citations, target_set):
    directory_path = "final_data_retracted/before_retraction/"
    os.makedirs(directory_path, exist_ok=True)

    with open(
        os.path.join(directory_path, "{}.csv".format(paperId)),
        "w",
        encoding="UTF8",
        newline="",
    ) as f:
        writer = csv.writer(f)
        header = ["citationID", "citationName", "citedReferences"]
        writer.writerow(header)

        for i in range(len(citations)):
            citation = citations[i]
            rsp = requests.get(
                "https://api.semanticscholar.org/graph/v1/paper/{}?fields=references".format(
                    citation["paperId"]
                ),
                headers={"x-api-key": S2_API_KEY},
            )
            try:
                rsp.raise_for_status()
            except requests.exceptions.HTTPError as e:
                print("Error: " + str(e))
                continue

            results = rsp.json()
            if results["references"]:
                citation_reference_set = set(
                    [
                        (r["paperId"], r["title"])
                        for r in results["references"]
                        if (r["paperId"] or r["title"])
                    ]
                )
                len_citation_reference_set = len(citation_reference_set)
                if len_citation_reference_set == 0:
                    continue
                # else:
                #     print("citation {} of high influence paper has {} references".format(i, len_citation_reference_set))

                intersection = citation_reference_set.intersection(target_set)
                len_intersection = len(intersection)
                if len_intersection > 0:
                    # print('')
                    # print(citation['title'])
                    # print("{} common citations:".format(len_intersection))
                    # for item in intersection:
                    #     print("  {}".format(item[0]))
                    #     print("  {}".format(item[1]))
                    writer.writerow(
                        [
                            citation["paperId"],
                            citation["title"],
                            "$$@$$".join(
                                [x[0] if x[0] else x[1] for x in intersection]
                            ),
                        ]
                    )
                # else:
                #     print("No common citations.")

            time.sleep(5)
        print("Created csv file.")

# %%
def get_data(paperId, retraction_date):
    rsp = requests.get(
        "https://api.semanticscholar.org/graph/v1/paper/{}?fields=url,citations,references".format(
            paperId
        ),
        headers={"x-api-key": S2_API_KEY},
    )
    rsp.raise_for_status()
    high_influence_paper = rsp.json()
    # print(high_influence_paper)
    citations_before_count = 0
    citations_after_count = 0
    citations_before_retraction = []
    citations_after_retraction = []
    citations_date_none = []
    target_set = set(
        [
            (r["paperId"], r["title"])
            for r in high_influence_paper["references"]
            if (r["paperId"] or r["title"])
        ]
    )
    len_target_set = len(target_set)
    if len_target_set == 0:
        print("1")
        exit(1)
    else:
        print("high influence paper has {} references".format(len_target_set))

    for i in range(len(high_influence_paper["citations"])):
        citation = high_influence_paper["citations"][i]

        citation_date = get_publication_date(citation["paperId"])

        if citation_date is None:
            citations_date_none.append(citation)
            continue

        if citation_date is not None:
            if citation_date < retraction_date:
                citations_before_retraction.append(citation)
                citations_before_count += 1

            else:
                citations_after_retraction.append(citation)
                citations_after_count += 1
    print(
        "There are {} citations before retraction and {} citations after retraction".format(
            citations_before_count, citations_after_count
        )
    )

    print(f"Before retraction: {citations_before_retraction}")
    create_csv_file(paperId, citations_before_retraction, target_set)

# %%
get_data("09f885deb1c88867c83cccafeeeaa468f91218e0", "2022/11/20")
# Out:
# high influence paper has 37 references
# Error fetching publication date for paperId 58d6aba7286628b0c97dc63a47884a1ea138e437: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/58d6aba7286628b0c97dc63a47884a1ea138e437?fields=publicationDate
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# There are 300 citations before retraction and 5 citations after retraction
# Before retraction: [{'paperId': 'd07018e290563f1d807f2d95d98a72c0a40b42f1', 'title': 'Sampled-data control of fuzzy systems'}, {'paperId': '9f6e2d365746e6b6d8836ea7ba14508ba767f996', 'title': 'Fuzzy switching function-based sliding mode controller design for T-S fuzzy descriptor systems'}, {'paperId': '9c544436a2bb673daa108766b59dff1827df7651', 'title': 'Membership functions dependent adaptive sliding mode fault‐tolerant control for uncertain T–S fuzzy systems with performance bounds'}, {'paperId': '360fa60299b7f99267ba7cbca98a0a185fd6d1f9', 'title': 'Disturbance rejection based tracking control design for fuzzy switched systems with time‐varying delays and disturbances'}, {'paperId': '345fdb9bf817e47e53dfb5d81b04511fe3fce687', 'title': 'Robust fault-tolerant control design for polynomial fuzzy systems'}, {'paperId': '6e307e86082110ecebe29bf673570f0f42112f36', 'title': 'Fixed-time integral sliding mode control design for a class of uncertain nonlinear systems based on a novel fixed-time stability condition'}, {'paperId': '145d6f43e7c9a65211bf226928c1dc34bf75ca71', 'title': 'Input–Output Finite-Time Stabilization of T–S Fuzzy Systems Through Quantized Control Strategy'}, {'paperId': 'd588e77ec54867b9c234bc3e45cf49c0312a67d2', 'title': 'Fixed-time Disturbance Observer-based Sliding Mode Control for Mismatched Uncertain Systems'}, {'paperId': 'f26ab6cdbddd368cb6772233eeeb4a7a0353a753', 'title': 'Sliding mode predictive control: A survey'}, {'paperId': '6ae8f15fe7b5cfe380c533c6e03b627cf65e7112', 'title': 'Finite-time synchronization of reaction-diffusion memristive neural networks: A gain-scheduled integral sliding mode control scheme.'}, {'paperId': '0cb8b72b9051b118a7c3440a34c15c080f7c37ae', 'title': 'Robust Adaptive Neural Sliding Mode Method for Coupled-Tank System Intelligent Control'}, {'paperId': '30c9d9cc7bbb905a2e3d1b88e273eeb3e529f717', 'title': 'Dissipativity-based finite-time asynchronous output feedback control for wind turbine system via a hidden Markov model'}, {'paperId': '78683e81808caa5967bf54ccad4f35746e00a31e', 'title': "Synthesis of a linear controller for a control system with interval parameters on a base of D‐partition in vertices of a coefficient's polyhedron of characteristic polynomial"}, {'paperId': 'a3d4745dacd7683b66c2853bbbbff4cef0737853', 'title': 'Method of Four Moments Mixture-A new approach for parametric estimation of Weibull Probability Distribution for wind potential estimation applications'}, {'paperId': 'f47f82cafbf0b1072485702f3327e130729d3fca', 'title': 'Cooperative control problem of Takagi-Sugeno fuzzy multiagent systems via observer based distributed adaptive sliding mode control'}, {'paperId': '7eccbd146689a0125f0c49c2a62f388f3ec34e58', 'title': 'Hybrid fuzzy sliding mode for stick-slip suppression in drill string systems'}, {'paperId': '5af1ddc14b5d3cd71fdd7d6802d438c22b3edc9e', 'title': 'Enhanced Stabilization of Discrete-Time Takagi–Sugeno Fuzzy Systems Based on a Comprehensive Real-Time Scheduling Model'}, {'paperId': 'b5ee161bff8c3385626c1ce7a52b95dc3771ff37', 'title': 'Event-triggered-based adaptive sliding mode control for networked linear control systems'}, {'paperId': 'fdc0b7e73d1c0c10a884fcfaa05796b4479dbc26', 'title': 'Asynchronous Output Feedback Control for a Class of Conic-Type Nonlinear Hidden Markov Jump Systems Within a Finite-Time Interval'}, {'paperId': '67007e5e7a310a641f1397b5086643cf5400a2b3', 'title': 'Adaptive Sliding Mode Fault-Tolerant Fuzzy Tracking Control With Application to Unmanned Marine Vehicles'}, {'paperId': '9df865f309e2ae24fe514c65163fc7cd5624d394', 'title': 'Dynamic modelling and PFL-based trajectory tracking control for underactuated cable-driven truss-like manipulator'}, {'paperId': '9829d0d4680984aa8b11c26b8a8bfaac06262c5d', 'title': 'A new continuous integral sliding mode control algorithm for inverted pendulum and 2-DOF helicopter nonlinear systems: Theory and experiment'}, {'paperId': '19db43b4cd62ab377f879ed2d3490a53f44f7ce7', 'title': 'Admi ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/35be3b29fd4b04332e1cad5851a6b1aff2a2080f?fields=references
# Created csv file.

# %%
for paper in top_15_retracted_papers_by_citations_json:
    get_data(paper["id"], paper["retraction_date"])
# Out:
# high influence paper has 37 references
# Error fetching publication date for paperId 8ffcf95281e44286f7ae348893b98a74c7ef7cb5: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/8ffcf95281e44286f7ae348893b98a74c7ef7cb5?fields=publicationDate
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# There are 301 citations before retraction and 5 citations after retraction
# Before retraction: [{'paperId': 'd07018e290563f1d807f2d95d98a72c0a40b42f1', 'title': 'Sampled-data control of fuzzy systems'}, {'paperId': '9f6e2d365746e6b6d8836ea7ba14508ba767f996', 'title': 'Fuzzy switching function-based sliding mode controller design for T-S fuzzy descriptor systems'}, {'paperId': '9c544436a2bb673daa108766b59dff1827df7651', 'title': 'Membership functions dependent adaptive sliding mode fault‐tolerant control for uncertain T–S fuzzy systems with performance bounds'}, {'paperId': '360fa60299b7f99267ba7cbca98a0a185fd6d1f9', 'title': 'Disturbance rejection based tracking control design for fuzzy switched systems with time‐varying delays and disturbances'}, {'paperId': '345fdb9bf817e47e53dfb5d81b04511fe3fce687', 'title': 'Robust fault-tolerant control design for polynomial fuzzy systems'}, {'paperId': '6e307e86082110ecebe29bf673570f0f42112f36', 'title': 'Fixed-time integral sliding mode control design for a class of uncertain nonlinear systems based on a novel fixed-time stability condition'}, {'paperId': '145d6f43e7c9a65211bf226928c1dc34bf75ca71', 'title': 'Input–Output Finite-Time Stabilization of T–S Fuzzy Systems Through Quantized Control Strategy'}, {'paperId': 'd588e77ec54867b9c234bc3e45cf49c0312a67d2', 'title': 'Fixed-time Disturbance Observer-based Sliding Mode Control for Mismatched Uncertain Systems'}, {'paperId': 'f26ab6cdbddd368cb6772233eeeb4a7a0353a753', 'title': 'Sliding mode predictive control: A survey'}, {'paperId': '6ae8f15fe7b5cfe380c533c6e03b627cf65e7112', 'title': 'Finite-time synchronization of reaction-diffusion memristive neural networks: A gain-scheduled integral sliding mode control scheme.'}, {'paperId': '0cb8b72b9051b118a7c3440a34c15c080f7c37ae', 'title': 'Robust Adaptive Neural Sliding Mode Method for Coupled-Tank System Intelligent Control'}, {'paperId': '30c9d9cc7bbb905a2e3d1b88e273eeb3e529f717', 'title': 'Dissipativity-based finite-time asynchronous output feedback control for wind turbine system via a hidden Markov model'}, {'paperId': '78683e81808caa5967bf54ccad4f35746e00a31e', 'title': "Synthesis of a linear controller for a control system with interval parameters on a base of D‐partition in vertices of a coefficient's polyhedron of characteristic polynomial"}, {'paperId': 'a3d4745dacd7683b66c2853bbbbff4cef0737853', 'title': 'Method of Four Moments Mixture-A new approach for parametric estimation of Weibull Probability Distribution for wind potential estimation applications'}, {'paperId': 'f47f82cafbf0b1072485702f3327e130729d3fca', 'title': 'Cooperative control problem of Takagi-Sugeno fuzzy multiagent systems via observer based distributed adaptive sliding mode control'}, {'paperId': '7eccbd146689a0125f0c49c2a62f388f3ec34e58', 'title': 'Hybrid fuzzy sliding mode for stick-slip suppression in drill string systems'}, {'paperId': '5af1ddc14b5d3cd71fdd7d6802d438c22b3edc9e', 'title': 'Enhanced Stabilization of Discrete-Time Takagi–Sugeno Fuzzy Systems Based on a Comprehensive Real-Time Scheduling Model'}, {'paperId': 'b5ee161bff8c3385626c1ce7a52b95dc3771ff37', 'title': 'Event-triggered-based adaptive sliding mode control for networked linear control systems'}, {'paperId': 'fdc0b7e73d1c0c10a884fcfaa05796b4479dbc26', 'title': 'Asynchronous Output Feedback Control for a Class of Conic-Type Nonlinear Hidden Markov Jump Systems Within a Finite-Time Interval'}, {'paperId': '67007e5e7a310a641f1397b5086643cf5400a2b3', 'title': 'Adaptive Sliding Mode Fault-Tolerant Fuzzy Tracking Control With Application to Unmanned Marine Vehicles'}, {'paperId': '9df865f309e2ae24fe514c65163fc7cd5624d394', 'title': 'Dynamic modelling and PFL-based trajectory tracking control for underactuated cable-driven truss-like manipulator'}, {'paperId': '9829d0d4680984aa8b11c26b8a8bfaac06262c5d', 'title': 'A new continuous integral sliding mode control algorithm for inverted pendulum and 2-DOF helicopter nonlinear systems: Theory and experiment'}, {'paperId': '19db43b4cd62ab377f879ed2d3490a53f44f7ce7', 'title': 'Admi ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/591d0bbbc69c8d1c0b998229c6e6b6e83900d715?fields=references
# Created csv file.
# high influence paper has 10 references
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# There are 266 citations before retraction and 259 citations after retraction
# Before retraction: [{'paperId': '6dc332df3238b6a3dd0b2bbf115f757a2f13a834', 'title': 'Predictive Analysis for the Detection of Covid-19 with Chest X-Ray Images Using Convolutional Neural Network'}, {'paperId': '6a833dd39ea906888b98a852ae8b06c54c3b04e8', 'title': 'A Novel Medical Support Deep Learning Fusion Model for the Diagnosis of COVID-19'}, {'paperId': '86b02310ad3e44894d63e5c9f91e8cb645cb8d32', 'title': 'Integration of cardiovascular risk assessment with COVID-19 using artificial intelligence.'}, {'paperId': '478c6e4b2cbc52719b6b049c7a7199e48d3968a1', 'title': 'Coronavirus 2019 (COVID-19) Detection Based on Deep Learning'}, {'paperId': 'd96faa68e9853503fd631af6fb6b367d03aa03a1', 'title': 'The Novel Approach to Modeling the Spread of Viral Infections'}, {'paperId': '7183f48bff48ff88e8550b4c067f9655cec64e03', 'title': 'COVID-19 Diagnosis from Chest X-ray Images Using Deep Learning Approach'}, {'paperId': 'b07e76b8754fee112b55825256eb17c03609ec5a', 'title': 'Efficient and visualizable convolutional neural networks for COVID-19 classification using Chest CT'}, {'paperId': '0adb25f059695d6ede25adb87c8ee3d7f7b3c37a', 'title': 'Deep Learning in the Detection and Diagnosis of COVID-19 Using Radiology Modalities: A Systematic Review'}, {'paperId': 'f6614e7ad7dc59d4a1fa912b3fae4037860a03ee', 'title': 'System for Quantitative Diagnosis of COVID-19-Associated Pneumonia Based on Superpixels With Deep Learning and Chest CT'}, {'paperId': '250c129799ed4601ddea3688b61f4b84d58e6f04', 'title': 'Automatic diagnosis of COVID-19 and pneumonia using FBD method'}, {'paperId': '239e92e8538846fd5e04803c7dfb80d2aef25126', 'title': 'Artificial Intelligence Facing COVID-19 Pandemic for Decision Support in Algeria'}, {'paperId': '70ed9e43dbd373f67fe191c560bdf663f44b7abd', 'title': 'Accuracy Improvement in Detection of COVID-19 in Chest Radiography'}, {'paperId': '8e54ff03f41366ec963a013ff8936aa7a76a85ed', 'title': 'A Survey of Artificial Intelligence and Internet of Things (IoT) based approaches against Covid-19'}, {'paperId': '20dd182b210418be46ddcaa8952cb7ad1a61c29f', 'title': 'CHS-Net: A Deep Learning Approach for Hierarchical Segmentation of COVID-19 via CT Images'}, {'paperId': '7fc30915fb1aa8c4dedffd4b67347e0ddcb5d2dd', 'title': 'CHS-Net: A Deep learning approach for hierarchical segmentation of COVID-19 infected CT images'}, {'paperId': 'a1e6d5d71294ee2d7e69fb61ae03bb55593be4d1', 'title': 'COVID-GATNet: A Deep Learning Framework for Screening of COVID-19 from Chest X-Ray Images'}, {'paperId': '0179a6ac86743c20f9353e99ab57500b7e72aafb', 'title': 'Severity Prediction of COVID-19 Patients Using Machine Learning Classification Algorithms: A Case Study of Small City in Pakistan with Minimal Health Facility'}, {'paperId': 'b2ac4de30d088619587e637e6812fcb2a7bf08ff', 'title': 'Patient Classification Using the Hybrid AHP-CNN Approach'}, {'paperId': 'c88332226782f40911d08aa91830eddc6eb6d33f', 'title': 'A Survey on Artificial Intelligence in Chest Imaging of COVID-19'}, {'paperId': 'e34b19d7008ca5081c3d6e76c98b78e66907c557', 'title': 'COVID-CLNet: COVID-19 Detection with Compressive Deep Learning Approaches'}, {'paperId': '5f98cfb7dacb288a8789776295980a1bf306fdf0', 'title': 'Collaborative Text and Image based Information Retrieval Model using BiLSTM and Residual Networks'}, {'paperId': 'bf5a8a7bcedf1a51fa08a12b45d8954c940a0787', 'title': 'COVID-19 Detection on CT Scans Using Local Binary Pattern and Deep Learning'}, {'paperId': '5baaa6fd8dcc3d124b8c192b6210f7550f2c4e56', 'title': 'Single-Shot Lightweight Model For The Detection of Lesions And The Prediction of COVID-19 From Chest CT Scans'}, {'paperId': 'f03c7a6194578218f7851f1990c6d3afaa9118c1', 'title': 'A Systematic Review on the Use of AI and ML for Fighting the COVID-19 Pandemic'}, {'paperId': '1c24c60fd08601aca365b54d531b8657b60c832e', 'title': 'A Systematic Review on the Use of AI and ML for Fighting the COVID-19 Pandemic'}, {'paperId': 'cc2df489966abf9f9d11bca5fda4be8dab8c3a66', 'title': 'Can So ...
# Created csv file.
# high influence paper has 53 references
# There are 179 citations before retraction and 0 citations after retraction
# Before retraction: [{'paperId': '5b1fc6812fd57b18ac2a7182a2a0b5201da1ed6f', 'title': 'Adaptive Fuzzy Backstepping Asymptotic Disturbance Rejection of Multiagent Systems With Unknown Model Dynamics'}, {'paperId': '16433d8d974cab477fb69e522a31e1c601c2508c', 'title': 'Robust fixed-time synchronization of uncertain fractional-order quaternion-valued neural networks'}, {'paperId': '940b4936f7f1b758a23695a3665e7a4e9bc83326', 'title': 'Finite-Time LOS Path Following of Unmanned Surface Vessels With Time-Varying Sideslip Angles and Input Saturation'}, {'paperId': '9bc70e3e514a9574abfee6faa4437c707bf0a6b7', 'title': 'Passivity‐based adaptive fault‐tolerant control for continuous‐time Markov jump PWA systems with actuator faults'}, {'paperId': 'bda3cb879fe1dee562675350df63b824c2c7d08c', 'title': 'Event-Triggered Synchronization of Multiple Fractional-Order Recurrent Neural Networks With Time-Varying Delays'}, {'paperId': '8e35c9f0f82f7987cbe3b7e72c84b7c8d760b6f9', 'title': 'Security Control for T–S Fuzzy Systems With Adaptive Event-Triggered Mechanism and Multiple Cyber-Attacks'}, {'paperId': '01101d3e05e3babd68e793ae4a56913bffafd9a3', 'title': 'Generalized non-fragile asynchronous mixed $$H_\\infty $$ and passive output tracking control for neutral Markov jump systems'}, {'paperId': '7669dd9cd33e35350e8efe5d1164ec62d5e25f6e', 'title': 'Finite-Time Synchronization for Switched Neural Networks via Quantized Feedback Control'}, {'paperId': 'bc58f1e00267a8b2a4a3834a34ceb8c88b441f9d', 'title': 'Adaptive fuzzy backstepping control for attitude stabilization of flexible spacecraft with signal quantization and actuator faults'}, {'paperId': 'ba45285a9bf0aa7f069069f37e3c0e972d25a43b', 'title': '$H_{\\infty }$ Weighted Integral Event-Triggered Synchronization of Neural Networks With Mixed Delays'}, {'paperId': '89ca2e1cd06d3280b5180e5c5d77edf8e86597ee', 'title': 'Vehicle lateral motion control via robust delay-dependent Takagi-Sugeno strategy'}, {'paperId': '6f4fb6997be245d53449eb623271565db6febce8', 'title': 'Finite‐time energy‐to‐peak quantized filtering for Markov jump networked systems under weighted try‐once‐discard protocol'}, {'paperId': '4e16f6d15dd4b36a5cedbc11845edd3a7c9bd220', 'title': 'Set-Membership Filtering Subject to Impulsive Measurement Outliers: A Recursive Algorithm'}, {'paperId': '06069b879b7c26f0556e3f230d90b030abcb6040', 'title': 'Dynamic Event-Based Non-Fragile Dissipative State Estimation for Quantized Complex Networks With Fading Measurements and Its Application'}, {'paperId': '72c6cd87a6646754f18b33c6562170f99141ec1b', 'title': 'On State Estimation for Discrete Time-Delayed Memristive Neural Networks Under the WTOD Protocol: A Resilient Set-Membership Approach'}, {'paperId': '8c3ff569e40afcdc4a265e4a8cd662ba901bbfd9', 'title': 'Finite-Time State Estimation for Delayed Neural Networks With Redundant Delayed Channels'}, {'paperId': '80dd9b2baa36906406ad125cfabceb2e36aafbdd', 'title': 'H ∞ state estimation for discrete memristive neural networks with signal quantization and probabilistic time delay'}, {'paperId': '085f3b06728c727fc2c683d821e5050c243a7079', 'title': 'Synchronization Control for Neutral Stochastic Delay Markov Networks via Single Pinning Impulsive Strategy'}, {'paperId': '86c5536c0b03bedfe243a3971ecba2c3e9b597de', 'title': 'Observer-Based Synchronization of Chaotic Systems Satisfying Incremental Quadratic Constraints and Its Application in Secure Communication'}, {'paperId': '063d7ede1dc1ab9548a447faea6b5e124e2f87c3', 'title': 'Application of fuzzy synchronization in the NLOS UV communication system'}, {'paperId': '420fb090f4fcea048a5121049b85dd739ec8bfa6', 'title': 'Moving horizon estimation with multirate measurements and correlated noises'}, {'paperId': '6253558ae490e8b3a642fbf620554aec04e3bc9a', 'title': 'Intermittent Control for Quasisynchronization of Delayed Discrete-Time Neural Networks'}, {'paperId': 'f9e346acf95b14684b47c9cf61f5acbe8f23792c', 'title': 'Command Filter-Based Adaptive NN Control for  ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/9d11aabd36ed7e622fce9fa3ae1c1df63d49d89a?fields=references
# Created csv file.
# high influence paper has 48 references
# Error fetching publication date for paperId 36348966b2559a28dd3799c58b891847762c6d38: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/36348966b2559a28dd3799c58b891847762c6d38?fields=publicationDate
# Error fetching publication date for paperId a2367f113c9da4ab55dcf7d83f5ce12a0a8375f0: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/a2367f113c9da4ab55dcf7d83f5ce12a0a8375f0?fields=publicationDate
# Error fetching publication date for paperId 6e7ba721a246ad5a3a4a2457af4105d165a0a679: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/6e7ba721a246ad5a3a4a2457af4105d165a0a679?fields=publicationDate
# Error fetching publication date for paperId 355b37ac5fa8c057f880ad03d6b38a4c4a7600e8: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/355b37ac5fa8c057f880ad03d6b38a4c4a7600e8?fields=publicationDate
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# There are 329 citations before retraction and 4 citations after retraction
# Before retraction: [{'paperId': '903398679b6b8717c5546927c3e819765e0a04f8', 'title': 'Robust Observer synthesis for Bilinear Parameter Varying system'}, {'paperId': 'd1da58ee85f6478591229ecbeb545a19a8a8a25d', 'title': 'CMAC-Based Sliding-Mode Control for Large-Scale Fuzzy Descriptor Systems'}, {'paperId': '7121723cc806049fa68a01a7d10b08e4d74e7c57', 'title': 'Relaxed Observer Design of Discrete-Time Takagi–Sugeno Fuzzy Systems Based on a Lightweight Gain-Scheduling Law'}, {'paperId': 'a0e661b1344763ffe97f9ac00b3ec962156db559', 'title': 'Event-triggered Nonfragile Observer Design for Interval Type-2 T-S Fuzzy Systems with Unmeasurable Premise Variables and Bounded Disturbances'}, {'paperId': '40b1202cfcea4aa39acae05a129a987fe7cbdea5', 'title': 'Event-triggered Non-fragile State Estimator Design for Interval Type-2 Takagi-Sugeno Fuzzy Systems via Quadratic Boundedness'}, {'paperId': 'cde5754e0672f9751b5351e170787227a9fc2982', 'title': 'Unknown Input Functional Observer Design for Discrete-Time Interval Type-2 Takagi–Sugeno Fuzzy Systems'}, {'paperId': '1c7adb1e9b3d2b523efaf2fe91c57a1caaa3ba31', 'title': 'Membership-function-dependent memory controller design for interval type-2 fuzzy systems under fading channels'}, {'paperId': 'cc5dd40608387c5749c355624bbc8579eac6f1d8', 'title': 'Relaxed Observer-Based State Estimation of Discrete-Time Takagi–Sugeno Fuzzy Systems Based on an Augmented Matrix Approach'}, {'paperId': 'fbb1e34e4939ddd12f46b2d36178c28424e97106', 'title': 'A T-S fuzzy state observer-based model predictive reset control for a class of fuzzy nonlinear systems with event-triggered mechanism'}, {'paperId': '77eb1a53768057744832c0949cf195daf2c1a8fc', 'title': 'Non-Fragile Observer-Based Adaptive Integral Sliding Mode Control for a Class of T-S Fuzzy Descriptor Systems With Unmeasurable Premise Variables'}, {'paperId': 'f3bd22faaf46ae97fd5191f65e52f41385e50c8d', 'title': 'Zonotopic set-membership state estimation for multirate systems with dynamic event-triggered mechanisms.'}, {'paperId': '0387f53ad8615bf9f9ecb6804ab191e9ecdc8e84', 'title': 'Takagi–Sugeno Fuzzy Observer-Based Magnetorheological Damper Fault Diagnosis Using a Support Vector Machine'}, {'paperId': '19735ee329303fcae3968a09f1a627ec08be7e94', 'title': 'Fuzzy Tracking Control for Markov Jump Systems With Mismatched Faults by Iterative Proportional–Integral Observers'}, {'paperId': '43e09160c2e0b154a140c4e21d6acc8967626fb5', 'title': 'Multi-Instant Observer Design of Discrete-Time Fuzzy Systems via An Enhanced Gain-Scheduling Mechanism'}, {'paperId': 'a50f1ea20d712ac2af6019a6b467794b78042876', 'title': 'Robust tracking control design for fractional-order interval type-2 fuzzy systems'}, {'paperId': '7129666681b124c3753fbb166228258fd33ec07e', 'title': 'Actuator fault detection for the discrete‐time switched systems based on delta operator approach'}, {'paperId': 'e79babe883dcf0a62dc37603f7755ae871b51e07', 'title': 'Actuator fault estimation for two-stage chemical reactor system based on delta operator approach'}, {'paperId': '60918b2707cd064ad6e01d9541eaaf8928be263e', 'title': 'Neural Network Command Filtered Control of Fractional-Order Chaotic Systems'}, {'paperId': 'f4f75d43056fdf6a019b00e34a0616844e5b168f', 'title': 'Disturbance observer-based LPV feedback control of a N-DoF robotic manipulator including compliance through gain shifting'}, {'paperId': 'c27a62d3051980e80b526582075dff4c6b39701b', 'title': 'A support vector regression (SVR)-based method for dynamic load identification using heterogeneous responses under interval uncertainties'}, {'paperId': 'cde347d4c757fa9026996802a655ff011e000997', 'title': 'Enhanced observer-based state estimation of discrete-time Takagi-Sugeno fuzzy systems via a distinctive multi-instant gain-scheduling law'}, {'paperId': 'ed8a643c0f20ea676745d7c89653032ece230e2f', 'title': 'Robust tracking control design for fractional-order interval type-2 fuzzy\xa0systems'}, {'paperId': 'a5f64988f162ed864c236ae0929ad26be1a81f47', 'title' ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/84c31fe146ef84289ae69ad1f39e9f7e914952e5?fields=references
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/bbb22b203786c459472fa2c42a9aad5bea4003ab?fields=references
# Created csv file.
# high influence paper has 63 references
# Error fetching publication date for paperId 57eb6a19d62c2eb59f746b29bef1085d11e7b919: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/57eb6a19d62c2eb59f746b29bef1085d11e7b919?fields=publicationDate
# Error fetching publication date for paperId b217dff9eb184d782d6fc5af4c4540ba60670c7c: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/b217dff9eb184d782d6fc5af4c4540ba60670c7c?fields=publicationDate
# Error fetching publication date for paperId b9d47b068a610d0a42bf62db7fc55865164b615b: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/b9d47b068a610d0a42bf62db7fc55865164b615b?fields=publicationDate
# There are 176 citations before retraction and 92 citations after retraction
# Before retraction: [{'paperId': '1a7c4e52f15c109435dde83a752f4de5f29d1144', 'title': 'Construction of Enterprise Management Business Model Based on Internet of Things RFID Technology'}, {'paperId': '2a53f454517e2584539f3c4bd156be8acdf7a9d8', 'title': 'A Fuzzy Best Worst approach to the determination of the importance level of digital supply chain on sustainability'}, {'paperId': '0ece6a78be3597f3c6ba1bbeac0ba9abe94cd554', 'title': 'The Impact of Block Chain and Smart Inventory System on Supply Chain Performance at Retail Industry'}, {'paperId': 'ebe97dd6f6f84d7945e217dd92d9bae96c470160', 'title': 'Analysis of Security Criteria for IoT-Based Supply Chain: A Case Study of FMCG Industries'}, {'paperId': 'd554bb32d6af009189d36e09e31cf1e9bccd4f42', 'title': 'Blockchain for consortium: A practical paradigm in agricultural supply chain system'}, {'paperId': '22d7a8c6f44b465274ad671e42b3ca2eb3df495c', 'title': 'Design and implementation of internet of things-based electrical monitoring system'}, {'paperId': 'dc44d3eaf3388b8cc0e68f32dfeafc95af011791', 'title': 'RETRACTED ARTICLE: IoT in a museum for interactive experience design'}, {'paperId': '09955cd2224e7be69868412c7db5d32c3d328c9e', 'title': 'Industry 4.0 and Supply Chain Performance in the Oil and Gas Industry'}, {'paperId': '23195fddfcd1001d6be7b236089936e4c1751e14', 'title': 'Determining the Importance of Barriers to IoT Implementation Using Bayesian Best-Worst Method'}, {'paperId': '54eb99e0d959c7abd6dd2214193a5b7ad13da328', 'title': 'Interplay among blockchain technology adoption strategy, e-supply chain management diffusion, entrepreneurial orientation and human resources information system in banking'}, {'paperId': '29cd2766f2eb7ebf5d62a31784b66d314a75641c', 'title': 'A novel prediction model for mobility tracing of users with hybrid metaheuristic concept'}, {'paperId': '8c30350fc99f9421f00cb52a9e67d6753e055785', 'title': 'A combined hesitant fuzzy MCDM approach for supply chain analytics tool evaluation'}, {'paperId': 'd68b7d27e2b932053d755c5ab4618c2f9d250100', 'title': 'RETRACTED ARTICLE: Impact of structural embeddedness on the performance of tourism supply chain integration: a social network perspective'}, {'paperId': 'c25a3de261b36deb20fd3c88fad9cf07a95cf2b3', 'title': 'Digitalization of construction supply chain and procurement in the built environment: Emerging technologies and opportunities for sustainable processes'}, {'paperId': 'f25f783d803b46502bde091b221a0400fa5d4d5d', 'title': "The influence of psychological abuse on children's aggressive behaviour"}, {'paperId': 'defbcbe5d9e9dcb5435d5348f6c11102a634d7f3', 'title': 'Improving thinking skills in early childhood using effective teaching strategies'}, {'paperId': 'bec2277f02c00e0f7e43d3d4da36e849be855fc7', 'title': 'Evaluation of occupational stress management for improving performance and productivity at workplaces by monitoring the health, well-being of workers'}, {'paperId': 'fe0cb68e171abfbfbea76746af22c7e78164d2e9', 'title': 'Internet of things challenges of sustainable supply chain management in the manufacturing sector using an integrated q-Rung Orthopair Fuzzy-CRITIC-VIKOR method'}, {'paperId': '6b68905bbb5ab657a059f74b8e50d159d4d0a5b9', 'title': 'Artificial intelligence on economic evaluation of energy efficiency and renewable energy technologies'}, {'paperId': 'f7bc9c382be11539125af82971638909d243757d', 'title': 'Solar power generation prediction based on deep Learning'}, {'paperId': '8e20cf506fb2c41beb8db32a261bddc6cd2c5258', 'title': 'Remanufacturing facility location for automotive Lithium-ion batteries: An integrated neutrosophic decision-making model'}, {'paperId': 'd5751579a70612e7405e4f6208a3a109c6527f83', 'title': 'An energy-efficient smart city for sustainable green tourism industry'}, {'paperId': 'c5a9f23018ca17c5f8e0166ac273f57480450502', 'title': 'Economic and environmental impacts of energy efficiency over smart cities and regulatory measures using a smart technological solution'}, {'paperId ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/3fbf451520511fc57356727fd8cefd43e0dc6f2d?fields=references
# Created csv file.
# high influence paper has 53 references
# Error fetching publication date for paperId 0eef96caebcd965dd50d20daa919faeeab0cbd77: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/0eef96caebcd965dd50d20daa919faeeab0cbd77?fields=publicationDate
# There are 172 citations before retraction and 40 citations after retraction
# Before retraction: [{'paperId': 'a4c39bd6da1a730faaac6a3fb3e674498229e30c', 'title': 'Enhanced Jaya algorithm: A simple but efficient optimization method for constrained engineering design problems'}, {'paperId': '8056897c060d21927d36bb1bd76e53479f5f376c', 'title': 'Research on a collocation approach and three metaheuristic techniques based on MVO, MFO, and WOA for optimal control of fractional differential equation'}, {'paperId': '2f10e1458641afe5f76ba6e18f725d0beb61601c', 'title': 'Computer Application in Game Map Path-Finding Based on Fuzzy Logic Dynamic Hierarchical Ant Colony Algorithm'}, {'paperId': '8c2fbfb64594eaaf60ffde61df2ce6f8263b54dd', 'title': 'A novel hybrid firefly–whale optimization algorithm and its application to optimization of MPC parameters'}, {'paperId': '7a882b4eba6e95d21398381f779edbb52eaee9ce', 'title': 'Self-encoding Barnacle Mating Optimizer Algorithm for Manpower Scheduling in Flow Shop'}, {'paperId': '9cf12ff8a9903c2120a4a97f909dd56f286cff4a', 'title': 'Deep learning for detecting distresses in buildings and pavements: a critical gap analysis'}, {'paperId': '6b48dd4fedd8d22aa55487fd309c1bb6da209efd', 'title': 'Hybrid marine predators algorithm for image segmentation: analysis and validations'}, {'paperId': '242c7a1e9a200c3b5ee8f14647181abd903d1e4c', 'title': 'A bilevel whale optimization algorithm for risk management scheduling of information technology projects considering outsourcing'}, {'paperId': '9c5035dc56e85b3e86dd86859253ad8194e19b81', 'title': 'Lightweight and green design of general bridge crane structure based on multi- specular reflection algorithm'}, {'paperId': '9bd71566973dac680b27ac71f5fdafcabfc14611', 'title': 'Extraction and mapping of component information of ancient buildings in Huizhou based on UAV technology'}, {'paperId': '6707d673a4d78eecc2c89c81e7be36f6c7107e9f', 'title': 'Cognitive Computing Integrated Methodology For Smart Decision Making And Problem-Solving'}, {'paperId': '78cd9006354ea6d366ca66b2185c26af6076baca', 'title': 'Review of Metaheuristics Inspired from the Animal Kingdom'}, {'paperId': '2f5a6114ce30c121e71d1445012672e709ea6c3e', 'title': 'A learning interactive genetic algorithm based on edge selection encoding for assembly job shop scheduling problem'}, {'paperId': '4702e8399056f8af5c559a29946926604e5f7487', 'title': 'Enhanced precision inspection of free-form surface with an improved whale optimization algorithm.'}, {'paperId': 'e6bd4a99560d51ab0dbfdd1b70d2873b47164317', 'title': 'A modified nature-inspired meta-heuristic methodology for heterogeneous unmanned aerial vehicle system task assignment problem'}, {'paperId': 'a3cf632e8c58e07732df898a8b9b7b65e9902b16', 'title': 'Discrete Jaya with refraction learning and three mutation methods for the permutation flow shop scheduling problem'}, {'paperId': '29bcf57884f16e727750332e6aa009551585441f', 'title': 'A wale optimization algorithm for distributed flow shop with batch delivery'}, {'paperId': '8dd5ef64c63906a66a1f79aad114a7f1493870ff', 'title': 'Improved elephant herding optimization using opposition-based learning and K-means clustering to solve numerical optimization problems'}, {'paperId': '5e2f7f1ac6aff3557351cec5659315c99cc6e568', 'title': 'A novel MPPT controller in PV systems with hybrid whale optimization-PS algorithm based ANFIS under different conditions'}, {'paperId': '1f9d4d8b100dfb631cc151f80ccc20823a8d2dae', 'title': 'Efficient scheduling approaches to time-constrained single-armed cluster tools with condition-based chamber cleaning operations'}, {'paperId': '3f41328acc39924063234e2c34b65a5e14ec6d9a', 'title': 'Improved Equilibrium Optimization Algorithm Using Elite Opposition-Based Learning and New Local Search Strategy for Feature Selection in Medical Datasets'}, {'paperId': '73b6d7a57a3a94da9bec76c0db97f751aa5f24e6', 'title': 'Constraint based local search for flowshops with sequence-dependent setup times'}, {'paperId': '882778ee505f1b538452de1926581f8f112817d1', 'title': 'Modified whale op ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/7c746ecdf6e5d00dc120060a747a71647efec3a6?fields=references
# Created csv file.
# high influence paper has 34 references
# Error fetching publication date for paperId b5cb9441da1b9076d8bb255f226a1ea6a6baf832: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/b5cb9441da1b9076d8bb255f226a1ea6a6baf832?fields=publicationDate
# Error fetching publication date for paperId None: 404 Client Error: Not Found for url: https://api.semanticscholar.org/graph/v1/paper/None?fields=publicationDate
# There are 136 citations before retraction and 24 citations after retraction
# Before retraction: [{'paperId': '7c4da3bbe0fb898518158782cf69e4a159d1af00', 'title': 'Küresel Bulanık Sayılara Dayalı TOPSIS Tekniğiyle Yeşil Tedarikçi Seçimi'}, {'paperId': '7458df745ad2492271a4a3bafe43532b96a1d4b4', 'title': 'A novel two-phase group decision-making model for circular supplier selection under picture fuzzy environment'}, {'paperId': '6e65a5d17a366740083567c8151f28d6ce8e4c44', 'title': 'EDAS ve WASPAS yöntemleriyle tıbbi malzeme tedarikçisi belirleme'}, {'paperId': '34ad4c9cf8a64cdf54fd1ec97dcd266d894b638c', 'title': 'The sourcing decision-making process in the era of digitalization: A new quantitative methodology'}, {'paperId': '0b01c8243e4bef43da0ca64a7b1beca5aac208b0', 'title': 'A Novel Approach for Risk Assessment of Building Damage via Metro Tunnel Construction'}, {'paperId': '21598c1a3bda4ac19c6b2829c9bea818d95775eb', 'title': 'Grey relational analysis method for typhoon vulnerability assessment of civil engineering structures based on the 2-tuple linguistic neutrosophic number'}, {'paperId': 'd3100c3ac73b0133906fcbdeb493de6da67a6c01', 'title': 'A Hybrid OPA and Fuzzy MARCOS Methodology for Sustainable Supplier Selection with Technology 4.0 Evaluation'}, {'paperId': 'afb2e1e6f578cf337151921086370ce1e9ab8322', 'title': 'Supplier selection and order allocation planning using predictive analytics and multi-objective programming'}, {'paperId': 'fd04c2e13d3caa99cb078565737f25b7996b9adf', 'title': 'Method for 2-tuple linguistic neutrosophic number MAGDM and applications to physical education teaching quality evaluation in colleges and universities'}, {'paperId': '12c9f4ff47af01ba8938a2589803cc8b6274613f', 'title': 'Circular Supplier Selection in the Construction Industry: A Sustainability Perspective for the Emerging Economies'}, {'paperId': '83fac5d59a11ee8c27d1dd5f397cdae4a45330e7', 'title': 'A Decision-Making Framework for University Student Sports Study Psychological Healthy Evaluation with 2-Tuple Linguistic Neutrosophic Numbers'}, {'paperId': '5de2386d1682ff7ef5c5d842d33b9abc90258e41', 'title': 'The Homogeneous MADM Methods: Is Trade-Off between Attributes Important?'}, {'paperId': 'c2bef3b3cf2a0e937086cfc7b21c75d740b4f290', 'title': 'Performance evaluation of family business strategic transition based on the 2-tuple linguistic neutrosophic number multiple attribute group decision making'}, {'paperId': '68030ba8c5e295e805c919b1a774e7fde8046dd9', 'title': 'An intelligent decision methodology for physical health evaluation of college students based on generalized 2-tuple linguistic neutrosophic geometric HM operators'}, {'paperId': '049ce13a50a01b1adee9101e21fd6eb61ee08fbe', 'title': 'A neutrosophic approach to evaluate the factors affecting performance and theory of sustainable supply chain management: application to textile industry'}, {'paperId': '0b3db27a958fb16fd3846263e329e3383f9dbde3', 'title': 'Gender inequality and self-publication are common among academic editors'}, {'paperId': '069d66c06c590010d5c23a63939e838dfd562155', 'title': 'Non-linear Neutrosophic Numbers and Its Application to Multiple Criteria Performance Assessment'}, {'paperId': '5b3ca1f35b0b84dbeef10fa29ea19dd33fa40696', 'title': 'Incorporating management opinion in green supplier selection model using quality function deployment and interactive fuzzy programming'}, {'paperId': '7866e7b3502bb1873601b5542ae838256ad3603e', 'title': 'Sustainable supplier selection using HF-DEA-FOCUM-MABAC technique: a case study in the Auto-making industry'}, {'paperId': 'dc99e5f2649f573dd0d3bff3eef4f8dfdd5dcb08', 'title': 'A robust multicriteria analysis for the post-treatment of digestate from low-tech digesters. Boosting the circular bioeconomy of small-scale farms in Colombia'}, {'paperId': '0e11edb699493cca94c5ef603ddc28036c49be50', 'title': 'Decision-making framework for\xa0supplier selection using an\xa0integrated MCDM approach in\xa0a\xa0lean-agile-resilient-green environment: evidence from Indian\xa0automotive sector'}, {'paperId': 'a4687c40f1d ...
# Created csv file.
# high influence paper has 48 references
# There are 157 citations before retraction and 7 citations after retraction
# Before retraction: [{'paperId': '6e307e86082110ecebe29bf673570f0f42112f36', 'title': 'Fixed-time integral sliding mode control design for a class of uncertain nonlinear systems based on a novel fixed-time stability condition'}, {'paperId': '9b32efb8c51a9b672866b18099eaed82eb8ac415', 'title': 'Memory characteristics-based generalized fuzzy dissipative robust control for multiple delayed uncertain jump systems'}, {'paperId': 'ef6548c0903c697aafadd27bdbd92876a568c87a', 'title': 'High-Precision Composite Control Based on Dual-Sampling-Rate Extended State Observer for Ultra-Low Speed Gimbal Servo System'}, {'paperId': '6ae8f15fe7b5cfe380c533c6e03b627cf65e7112', 'title': 'Finite-time synchronization of reaction-diffusion memristive neural networks: A gain-scheduled integral sliding mode control scheme.'}, {'paperId': '4d50da6cac9ba9d3744a74bbb92fbe1d7146d1c6', 'title': 'SMC-based model-free tracking control of unknown autonomous surface vehicles.'}, {'paperId': '23448c0d8cda234bb8eca1f024a96b4a6cf09999', 'title': 'Stability and Control of Fuzzy Semi-Markov Jump Systems Under Unknown Semi-Markov Kernel'}, {'paperId': '7036f950d4c0e1f0ad860cb8bda8ae3aeb9823e1', 'title': 'Dynamic event-based sliding mode security control for singular Semi-Markov jump LPV systems against deception attacks.'}, {'paperId': '4d64efa8baa096855b71f46aa2075c6edbea21f2', 'title': 'Interval type-2 generalized fuzzy hyperbolic modelling and control of nonlinear systems'}, {'paperId': '05c6491d81ea7fc347895e10316e0bfa344cb0af', 'title': 'Filter for Positive Stochastic Nonlinear Switching Systems With Phase-Type Semi-Markov Parameters and Application'}, {'paperId': '2a92422d8412d199763d31f36d4de84330e40e9c', 'title': 'An algorithm of fuzzy edge detection for wetland remote sensing image based on fuzzy theory'}, {'paperId': '67db728c43ff05fb9022af94c189def6048b119f', 'title': 'Stackelberg Game Theory-Based Optimization of High-Order Robust Control for Fuzzy Dynamical Systems'}, {'paperId': '472ee1f5c3533a8cee9f9ae52f352472d5900ab1', 'title': 'Modified Luo converter based FOPID controller for torque ripple minimization in BLDC drive system'}, {'paperId': '54a63ed658dc9d68eeaa3645541ca043a6cb1b69', 'title': 'Optimal Sliding Mode Control Design for Constrained Uncertain Nonlinear Systems Using T–S Fuzzy Approach'}, {'paperId': 'b5ee161bff8c3385626c1ce7a52b95dc3771ff37', 'title': 'Event-triggered-based adaptive sliding mode control for networked linear control systems'}, {'paperId': 'a6c6b33c1c4a7c53f5c37a9820cb88b3583e1952', 'title': 'Composite Anti-disturbance Quantized Control for Interconnected Semi-Markovian Systems With Multiple Disturbances and Actuator Faults'}, {'paperId': 'fdc0b7e73d1c0c10a884fcfaa05796b4479dbc26', 'title': 'Asynchronous Output Feedback Control for a Class of Conic-Type Nonlinear Hidden Markov Jump Systems Within a Finite-Time Interval'}, {'paperId': 'ad95a2d74127c47c0c22e19eb4c17e99b677c31c', 'title': 'Optimal SINR-Based DoS Attack Scheduling for Remote State Estimation via Adaptive Dynamic Programming Approach'}, {'paperId': '67007e5e7a310a641f1397b5086643cf5400a2b3', 'title': 'Adaptive Sliding Mode Fault-Tolerant Fuzzy Tracking Control With Application to Unmanned Marine Vehicles'}, {'paperId': '25e1b2773fd1dcb92aa283e0138527948fa18d15', 'title': 'Reliable H∞\xa0and Passive Fuzzy Observer-Based Sliding Mode Control for Nonlinear Descriptor Systems Subject to Actuator Failure'}, {'paperId': 'f983d58e31f4b2a4772fb939707dea207fec7ea5', 'title': 'Reliable H∞ and Passive Fuzzy Observer-Based Sliding Mode Control for Nonlinear Descriptor Systems Subject to Actuator Failure'}, {'paperId': 'ce587bf61b0f098a672dc924c39b3e167e8ef732', 'title': 'Implementation of adaptive fault‐tolerant tracking control for robot manipulators with integral sliding mode'}, {'paperId': 'a2087bae4c343eb37f5364b1ea4a4a119da6cc86', 'title': 'Sliding Mode Control of Markovian Jump Fuzzy Systems: A Dynamic Event-Triggered Method'}, {'paperId': '62c8a432800139fd2491b588cab34 ...
# Created csv file.
# high influence paper has 42 references
# There are 47 citations before retraction and 67 citations after retraction
# Before retraction: [{'paperId': '58993ea6be29c1a05d5cf75674716619452358f0', 'title': 'A new hybrid method for predicting ripping production in different weathering zones through in situ tests'}, {'paperId': 'f1c0b4c681dd6c5a3d1e1d94d015e4afe8806a89', 'title': 'Retraction Note to: Analysis of influential factors for predicting the shear strength of a V-shaped angle shear connector in composite beams using an adaptive neuro-fuzzy technique'}, {'paperId': '2a4897b79752453112c67d53a5a3a58a0bf9efce', 'title': 'Experimental investigation on the effect of cementitious materials on fresh and mechanical properties of self-consolidating concrete'}, {'paperId': '50005550c306b2dda7a5ec5aaeda4ad7a05c16dd', 'title': 'Retracted: Estimation of important variables for strength of concrete with high performance based on neuro fuzzy logic approach'}, {'paperId': 'c3b076f12bcdea3ef1f374b8fca7855dbcaa5c8a', 'title': 'UML diagrams for dynamical monitoring of rail vehicles'}, {'paperId': '283329e1add163908a1407f801922cef9d221815', 'title': 'Predictive model based on Adaptive Neuro-Fuzzy Inference System for estimation of Cephalexin adsorption on the Octenyl Succinic Anhydride starch'}, {'paperId': 'd540027f75fb8d39fbf1418a632588213f7c86cb', 'title': 'Analysis of the Seismic Performance of a Two-Span Specially Shaped Column Frame'}, {'paperId': '7a29db9c916ac1341379b590bee20a747f22da93', 'title': 'Performance evaluation of hybrid FFA-ANFIS and GA-ANFIS models to predict particle size distribution of a muck-pile after blasting'}, {'paperId': '7817574cc6591f4104f3a2fdca6bfd0011dc94f1', 'title': 'Performance evaluation of hybrid FFA-ANFIS and GA-ANFIS models to predict particle size distribution of a muck-pile after blasting'}, {'paperId': 'd5c9ef09c253b125dfd53d04d0dab18f386b3d16', 'title': 'Deep neural network and whale optimization algorithm to assess flyrock induced by blasting'}, {'paperId': '652101d57ff4867ba8a3224d3dc907c412d56dfe', 'title': 'Evaluation of Concrete Corrosion using EMI Sensor'}, {'paperId': '807eee28b7276b3a03f6721f61b1f77da768f699', 'title': 'Developed comparative analysis of metaheuristic optimization algorithms for optimal active control of structures'}, {'paperId': 'b5f723cb7d2f1bc5fa4ac56af248fadb6252814a', 'title': 'Potential of adaptive neuro-fuzzy methodology for investigation of heat transfer enhancement of a minichannel heat sink'}, {'paperId': '205441fbc997a5b560d278bf9960464e9408d311', 'title': 'Potential of neuro-fuzzy methodology for forecasting of outdoor thermal comfort index at urban open spaces'}, {'paperId': 'a412b20fda7e4550c81bd7632a65c398603cd4b8', 'title': 'Developed comparative analysis of metaheuristic optimization algorithms for optimal active control of structures'}, {'paperId': '654e916dcd4a735e0b13195286663c3ed5ec3a26', 'title': 'Development of a novel hybrid intelligent model for solving engineering problems using GS-GMDH algorithm'}, {'paperId': '49b476c3c55fada81618b458ff589fb06df0c4c2', 'title': 'Developing new tree expression programing and artificial bee colony technique for prediction and optimization of landslide movement'}, {'paperId': '822bc6f1b048fdb63c8958d8fc8eba718c9dfe9c', 'title': 'Computational optimized finite element modelling of mechanical interaction of concrete with fiber reinforced polymer'}, {'paperId': 'a11cf4d96d5d9c8cef16d263047a6d1db8612bae', 'title': 'Econometric model of non-performing loans determinants'}, {'paperId': 'f442759c6e1f59a0480bc508584d590a8cce6844', 'title': 'Assessment of electronic system for e-patent application and economic growth prediction'}, {'paperId': '50c41315b79a2843a7a1a1e1b845b50a7036f8e7', 'title': 'Novel approach for forecasting the blast-induced AOp using a hybrid fuzzy system and firefly algorithm'}, {'paperId': 'e897d694e893eda944660f9dea645630f1909413', 'title': 'Hysteretic performance of stubby Y-type perfobond rib shear connectors depending on transverse rebar'}, {'paperId': '15fdeea0dad9df77f3cc7ba25f0ee060646f8b03', 'title': 'A Monte Car ...
# Created csv file.
# high influence paper has 36 references
# There are 131 citations before retraction and 6 citations after retraction
# Before retraction: [{'paperId': 'f94063f1f9c0b3decfd22b193929f72bce27f66f', 'title': 'Reliable Fuzzy Sampled-Data Control for Nonlinear Suspension Systems Against Actuator Faults'}, {'paperId': '7d30a0428a3539e49d2807b9c5e486f35cca8e1d', 'title': 'Active disturbance rejection formation control for multi-agent systems with multiple leaders'}, {'paperId': 'a14175c9ecf292e022cccda5f539ffe292a7d8ed', 'title': 'Reliable Fuzzy Dynamic Positioning Tracking Controller for Unmanned Surface Vehicles Based on Aperiodic Measurement Information'}, {'paperId': '329010f2b088371ac27ec295c3e39bd9c498dfa9', 'title': 'Stabilization Criteria for T–S Fuzzy Systems With Multiplicative Sampled-Data Control Gain Uncertainties'}, {'paperId': '99d0adbea209191c8a598829ba1704b67cd1adaf', 'title': 'Event‐triggered control for sampled‐data set stabilization of switched delayed boolean control networks'}, {'paperId': '4d50da6cac9ba9d3744a74bbb92fbe1d7146d1c6', 'title': 'SMC-based model-free tracking control of unknown autonomous surface vehicles.'}, {'paperId': '580b7ba5ecfde4ee8b9debdfd6e8b2d3007a8827', 'title': 'Lyapunov-Based Approach to Sampled-Data Set Stabilization of Constrained Boolean Control Networks'}, {'paperId': '03ac235407e0be7d7c9f4f78c47bf45f960e2167', 'title': 'Decentralized sampled-data <mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" altimg="si43.svg"><mml:mrow><mml:msub><mml:mrow><mml:mi>H</mml:mi></mml:mrow><mml:mrow><mml:mi>∞</mml:mi></mml:mrow></mml:msub></mml:mrow></mml:math> fuzzy filtering with exponential time-varying gains for nonlinear '}, {'paperId': '2965546e091a5c37044cba32dff9519817524cf9', 'title': 'Practical stability of a nonlinear system with delayed control input'}, {'paperId': 'f0bdbad9bf486b236586130c1ccad007d34b2c2a', 'title': 'Extended-state-observer-based Error-driven Adaptive Nonlinear Feedback Control of Electrical-optical Gyro-stabilized Platform via Modified Dynamic Surface Control with Error Constraint'}, {'paperId': '456d6d8b86dc0e7045817c9ae27c433f084f96b4', 'title': 'Admissibility Analysis of a Sampled-Data Singular System Based on the Input Delay Approach'}, {'paperId': '93dba6bba7d38a9c42e02471ec62f43715ff4b1f', 'title': 'Finite-time reliable sampled-data control for fractional-order memristive neural networks with quantisation'}, {'paperId': 'ed93f692fca35f1b8e1e0c005bc96a8a94455d73', 'title': 'Observer‐based guaranteed cost control for IT‐2 stochastic fuzzy coupled neural networks with Markov switching topology'}, {'paperId': 'eee641cdc09de0e13e151cf9d7d04624ee85f897', 'title': 'Neural network‐based tracking control of autonomous marine vehicles with unknown actuator dead‐zone'}, {'paperId': '7466eda43a6ee5d42af1663125a3f501e4cdb413', 'title': 'Improved sampled data fuzzy controller for nonlinear system: The event‐triggered approach'}, {'paperId': '14cb95fd522541f9d76d219c2e6867faa0c68d0f', 'title': 'Event-Triggered Sliding Mode Control of Fuzzy Systems via Artificial Time-Delay Estimation'}, {'paperId': '5349554f79704bed7e81d14ed997173fb5366258', 'title': 'Neural Network-Based Sampled-Data Control for Switched Uncertain Nonlinear Systems'}, {'paperId': 'b19bcba765ac155b40697bc414ccdeb4453d1e9b', 'title': 'Stochastic Sampled-Data Exponential Synchronization of Markovian Jump Neural Networks With Time-Varying Delays'}, {'paperId': '008d8dec07cefe4fec91afe40dcb3730be2c8488', 'title': 'Mixed H∞ and passivity analysis for T-S fuzzy system with non-fragile memory sampled-data control via augment Lyapunov-Krasovskii functional'}, {'paperId': 'd21cf5f80afaeb8408677ffd044f54dacbf5a09e', 'title': 'Design of H∞-based sampled-data control for fuzzy Markov jump systems with stochastic sampling'}, {'paperId': '79ad6ec85c9a371d374f8701bfb839fde2fa2bf4', 'title': 'Event-triggered Control for Sampled-Data Set Stabilization of Switched Delayed Logical Control Networks'}, {'paperId': '8597e1a6756785374351d40d7149ee791ad6508a', 'title': 'Adaptive Nonlinear Hierarchical Control for a Rotorcraft Transporting a Cable ...
# Error: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/14cb95fd522541f9d76d219c2e6867faa0c68d0f?fields=references
# Created csv file.
# high influence paper has 71 references
# There are 153 citations before retraction and 14 citations after retraction
# ...
# Created csv file.
# high influence paper has 50 references
# There are 125 citations before retraction and 21 citations after retraction
# Before retraction: [{'paperId': 'b7b49e172ca956c20144cf646c05c1d615d1333e', 'title': 'A Hyb-WGWO and Deep EMC–based Intelligent E-healthcare monitoring model for patient condition diagnosis in internet of things connected applications'}, {'paperId': '773c17257512ba6fd9d3504859842d070764d044', 'title': 'Privacy Protection Technology in IOT Data Storage Based on Blockchain'}, {'paperId': '532a0fbb81b8ac60e686f7c84e9beef5b10134c8', 'title': 'An Integrated Secure Efficient Computing Architecture for Embedded and Remote ECG Diagnosis'}, {'paperId': '5fb4bf7caf7dd906ecfde27f6ebcf5137a75004f', 'title': 'A secure social multimedia sharing scheme in the TSHWT_SVD domain based on neural network'}, {'paperId': 'd999e99b26307c5404260400bc9718ef3d9379a2', 'title': 'Secure medical image sharing for smart healthcare system based on cellular neural network'}, {'paperId': '02469b0598feb79acbbb55d1521ea1df3eba2073', 'title': 'Security enhancement of the cloud paradigm using a novel optimized crypto mechanism'}, {'paperId': 'aaa0e835ec775706d7c627b7002b11af1aa54181', 'title': 'A robust medical image steganography approach based on particle swarm optimization algorithm and quantum walks'}, {'paperId': 'f1aa5c12066a16346a127786c6221e6b916aac32', 'title': 'A survey on DE – Duplication schemes in cloud servers for secured data analysis in various applications'}, {'paperId': 'dc913c8c9209954cb3f21105c7b45e394843d37f', 'title': 'An optimal elliptic curve cryptography based encryption algorithm for blockchain-enabled medical image transmission'}, {'paperId': 'c169d4582a79bf4f6e24843a9683109c600eb9bd', 'title': 'Hybrid Visual and Optimal Elliptic Curve Cryptography for Medical Image Security in Iot'}, {'paperId': 'e16ecbbde9c1bd4fc9b4cddfab48bd9dc0c71780', 'title': 'Blockchain-Based Internet-of-Things for Secure Transmission of Medical Data in Rural Areas'}, {'paperId': '09d4c7def5f01a7d94ae918f26eca5d166bbbbfe', 'title': 'A Comprehensive Study On Medical Image Security Algorithms'}, {'paperId': '276883f1541f0d05d5fdb854ef7feb230d1635f5', 'title': 'Visualization Analysis and Trends in Indonesian Internet of Things Research Using Bibliometrics'}, {'paperId': 'e2af284a5bd92580f4059a13b28ade45a4b1b202', 'title': 'A novel communication‐aware adaptive key management approach for ensuring security in IoT networks'}, {'paperId': 'c4c4991240690e7ab444fbc7afaaf3e9c550a83d', 'title': 'Instant-Hybrid Neural-Cryptography (IHNC) based on fast machine learning'}, {'paperId': '769d44127d689ce1a86d80f3fb41962236486d31', 'title': 'An image encryption algorithm based on Fibonacci Q-matrix and genetic algorithm'}, {'paperId': 'fda03cf8e4c7c702e8401b7246420a0bac4feb0a', 'title': 'MACO-ECDH BASED SECURE DATA TRANSMISSION IN MANETS'}, {'paperId': '9220bf87e85982915827a586769bd26421fc0adf', 'title': 'Construction of a Multimedia Education Resource Security Model Based on Multistage Integration'}, {'paperId': '122880e74f71b9fdd96de4d69fb2c0d1dd83ea53', 'title': 'The internet of medical things and artificial intelligence: trends, challenges, and opportunities'}, {'paperId': '64ae4e2cca2ba7e23dfc411a2e138eaec9d5cb6d', 'title': 'Secure Image Encryption Using Chaotic, Hybrid Chaotic and Block Cipher Approach'}, {'paperId': '073d760ce3a07c53702cb5588ebce55c177b9b24', 'title': 'Visual Presentation and Trend Derivation of the Medical Big Data Research based on a Multi-level Bibliometric Analysis'}, {'paperId': '21a893b79c4b9b4f79f16dce1180017a7a19e75a', 'title': 'Computer Graphic Image Design and Visual Communication Design in the Internet of Things Scenario'}, {'paperId': '1355e44a3dcd4af77ad34bb6edbe6f5fec563bf8', 'title': 'Image encryption algorithm based on a 2D-CLSS hyperchaotic map using simultaneous permutation and diffusion'}, {'paperId': 'f18ee54c64838ab1e120e4c1535b5a5b8adcd45e', 'title': 'IMGTXT: Image to Text Encryption Based on Encoding Pixel Contrasts'}, {'paperId': '0f45078ef6ca0135485a41a0fb7de597b8e2ab0b', 'title': 'Security in Internet of Things (IoT): Challenges an ...
# Created csv file.
# high influence paper has 27 references
# There are 78 citations before retraction and 59 citations after retraction
# Before retraction: [{'paperId': 'dcde7902d85417dca71a1daae2eb3c7057821dcc', 'title': 'Three-Dimensional Architectural Modeling and Decoration Design System based on Virtual Reality'}, {'paperId': '65bf9b09651c03e1465f108ab04f7550f6436036', 'title': 'Application of discrete element method (DEM) in characterization of bond-slip behavior in RC beams with confinement subjected to corrosion'}, {'paperId': '66a28c343220bb10563d865bc1a8ff05cb0c2723', 'title': 'Influence of porosity and cement grade on concrete mechanical properties'}, {'paperId': '0f91bd05d8e6df0d6aa25fa71c02a0f0315be379', 'title': 'Nonlocal dynamic modeling of mass sensors consisting of graphene sheets based on strain gradient theory'}, {'paperId': '9fe9c99ea5164ef98ab0938ad969c3b402312697', 'title': 'Recent Trends in Prediction of Concrete Elements Behavior Using Soft Computing (2010–2020)'}, {'paperId': '8b8d6f7ba014d1f4179709d2daa17b100c413138', 'title': 'Recent Trends in Prediction of Concrete Elements Behavior Using Soft Computing (2010–2020)'}, {'paperId': '5ea3a1b21a52b45154189ee56c0bc7ee85832fa3', 'title': 'Computational parameter identification of strongest influence on the shear resistance of reinforced concrete beams by fiber reinforcement polymer'}, {'paperId': '4d9c558f4deebead5f1e82db8c47666241122868', 'title': 'Developing a hybrid adoptive neuro-fuzzy inference system in predicting safety of factors of slopes subjected to surface eco-protection techniques'}, {'paperId': '658d8e52edeb20fd55c0b02e0403c5c916ec9872', 'title': 'The effects of ABC, ICA, and PSO optimization techniques on prediction of ripping production'}, {'paperId': '28f206301696a9ff2bed9a043ad1a78813126413', 'title': 'Experimental study on shaped steel shear connectors used in large-scale composite structures'}, {'paperId': '38f92d987eafb9cc6a82e9d8b97f4ffd47bdf798', 'title': 'Chaotic simulation of the multi-phase reinforced thermo-elastic disk using GDQM'}, {'paperId': 'c20bf78f8dfc6c52355782720ef10de3d36a5cbd', 'title': 'An improved adaptive neuro-fuzzy inference system using probability trajectory-based clustering ensemble'}, {'paperId': '5c3b03e279532282441ef92f38bc314fef2dfc43', 'title': 'Development of neuro-fuzzy and neuro-bee predictive models for prediction of the safety factor of eco-protection slopes'}, {'paperId': '830ee8d8767d55403c5ce63ccc149302547db816', 'title': 'Application of extreme learning machine in behavior of beam to column connections'}, {'paperId': '7010f8a503b3439b46d8b6afb9993d3f8c99a229', 'title': 'Optimization approach of passive cool skin technology application for the Building’s exterior walls'}, {'paperId': 'f4f96885d5f027d8ece858a1ecfb7179f4dc8905', 'title': 'Performance assessment of buckling restrained brace with tubular profile'}, {'paperId': '2271324462f80c13650339606b656452fc6690f8', 'title': 'Prediction of Lateral Deflection of Small-Scale Piles Using Hybrid PSO–ANN Model'}, {'paperId': '62ad86c6911aaa928127a7e2a29f5af76d110f28', 'title': 'Estimation capabilities of biodiesel production from algae oil blend using adaptive neuro-fuzzy inference system (ANFIS)'}, {'paperId': '13173e1139950c24d0c56da5d5364e17d02bbb28', 'title': 'Elevated temperature resistance of concrete columns with axial loading'}, {'paperId': '0c214bc2000cdf31c1340ac3af0c6bd8325b38f6', 'title': 'Development of a Group Method of Data Handling Technique to Forecast Iron Ore Price'}, {'paperId': 'bf6db5188030cf34f0899e378501fea21b607609', 'title': 'Utilization of Support Vector Models and Gene Expression Programming for Soil Strength Modeling'}, {'paperId': '5910d0cc0bd28fe15ee65faf9b470ac50e317f11', 'title': 'Utilization of Support Vector Models and Gene Expression Programming for Soil Strength Modeling'}, {'paperId': 'ae6689714864daeb16ad6ddf8213acf5fe3da227', 'title': 'A novel approach to predict shear strength of tilted angle connectors using artificial intelligence techniques'}, {'paperId': '74d6489a05e2b7d300fbfa99dbda6be9bbcb38d7', 'title': 'Retraction Note to: Potential of so ...
# Created csv file.
# high influence paper has 52 references
# There are 124 citations before retraction and 14 citations after retraction
# Before retraction: [{'paperId': '20cd51122da3521345f80c0075e7664cb4c216bd', 'title': 'Chapter 8 A naturopathy knowledge graph and recommendation system to boost the immune system KISS: Knowledge-based Immune System Suggestion'}, {'paperId': '9815fde597038afca8f15622fb68203cb4917adc', 'title': 'Smart IoMT Framework for Supporting UAV Systems with AI'}, {'paperId': 'aedc2ea3bde9e4b1d3633d67347479fa3c259c78', 'title': 'Owl Ontology for Liver Diseases Using Protégé & WEB-V-OWL'}, {'paperId': '7dad402aa6b904920410a77473690e437e61ebc7', 'title': "Personalized ontology and deep training tree‐based optimal gated recurrent unit‐recurrent neural network for prediction of students' behavior"}, {'paperId': 'dc14eb52b3223687356beabaf1db59c986d012fc', 'title': 'An Empirical Investigation of Personalized Recommendation and Reward Effect on Customer Behavior: A Stimulus–Organism–Response (SOR) Model Perspective'}, {'paperId': 'eda882cb413e558897277797e42a28cc6e1e85b2', 'title': 'An effective explainable food recommendation using deep image clustering and community detection'}, {'paperId': '3e5d29625d095e724e8c1676bad3e97f375e9580', 'title': 'Semantic models for IoT sensing to infer environment-wellness relationships'}, {'paperId': '2f3f3d8656d4b64c14fdc6a891ee0517053a2d83', 'title': 'Application and Challenges of IoT Healthcare System in COVID-19'}, {'paperId': 'c49aa08df2677e2da8d4da8fd4c517037eaa816a', 'title': 'Factors Affecting the Ability of Local People to Participate in Community-Based Tourism in the Non Nuoc Cao Bang UNESCO Global Geopark Viet Nam'}, {'paperId': '1417473ead393296589648a0e745cb2dff009014', 'title': 'A systematic review of healthcare recommender systems: Open issues, challenges, and techniques'}, {'paperId': 'c22869fad0a245363a54e85ce51f66e6c6dc0f3a', 'title': 'A real-time IoT-based botnet detection method using a novel two-step feature selection technique and the support vector machine classifier'}, {'paperId': 'caa043a58dd53090cd39f103988521d03fed4fb1', 'title': 'Understanding the efficiency of technological transformation in the public health service act'}, {'paperId': '389db484d8f98c2d482e5bef03a38f99e6643db1', 'title': 'Wisdom Tourism Management Mode in the Background of Big Data of the Internet of Things'}, {'paperId': '0baead7f0cf9c03809217a01279caac154eb9a13', 'title': 'Application of Internet of Things and Sensors in Healthcare'}, {'paperId': '3a7de2ec6e038d83e360f624b7903b95a9c400b5', 'title': 'Context-aware Based Personalized Recommendation on Mobile for Monitoring Excessive Sugar Consumption of Thai Adolescents'}, {'paperId': 'dccf5a872615f41ec6204609bb2bb727678d85b5', 'title': 'Dew computing-assisted cognitive Intelligence-inspired smart environment for diarrhea prediction'}, {'paperId': '99558fff89a0226e52c390be6febd22171d7e889', 'title': 'A Fair and Safe Usage Drug Recommendation System in Medical Emergencies by a Stacked ANN'}, {'paperId': '80932b4cd48f8d8d143d3ad14cfe14b244676ed3', 'title': 'Diagnosis of Chronic Diseases Based on Patients’ Health Records in IoT Healthcare Using the Recommender System'}, {'paperId': '4a3f83de09886db742b17bc8f70e79592c144ede', 'title': 'Cognitive Framework of Food Quality Assessment in IoT-Inspired Smart Restaurants'}, {'paperId': '6ea5796868aa574370e0064c1cbee9a4e8af9f03', 'title': 'Recommender system for health care analysis using machine learning technique: a review'}, {'paperId': 'dfcd4b4d621da55a417b536cd7c0d8a0a2a03bef', 'title': 'Intelligent unsupervised learning method of physical education image resources based on genetic algorithm'}, {'paperId': 'd4aa9ab5b41f0a92d06fb4f26a8b0f86ecd0fd15', 'title': 'Design of a Smart Art Classroom System Based on Internet of Things'}, {'paperId': '2bff094c8d8bbe2bc6f153acba6b789f1c602909', 'title': 'Survey on the Objectives of Recommender Systems: Measures, Solutions, Evaluation Methodology, and New Perspectives'}, {'paperId': '2d7dca71ebe1f438ee2fb2d0fa1907c1612da355', 'title': 'Sequential Recommendation with User Evolving Prefe ...
# Created csv file.
